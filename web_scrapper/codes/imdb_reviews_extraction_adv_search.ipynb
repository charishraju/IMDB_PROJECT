# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np 
import pandas as pd 
import random
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait,Select
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import requests
import subprocess
import re
from tqdm import tqdm
tqdm.pandas()

import os
os.chdir(os.path.abspath(os.path.join(os.getcwd(), "..", "..")))

# %%
from utils.web_scrapping import random_scroll,scroll_to_element,scroll_to_bottom
from logger import logger

# %% [markdown]
# # setting up selinium web driver and opening the webpage

# %%
logger.info(f"starting chrome using selenium")
# Out:
# 2025-03-12 15:53:25 - [INFO] - (3841766469.py:1) - starting chrome using selenium

# %%
def launch_chrome_with_debugging(url):
    chrome_path = r"C:\Program Files\Google\Chrome\Application\chrome.exe"
    # user_data_dir = r"C:\\Users\\Harish raju\\AppData\\Local\\Google\\Chrome\\User Data\\Default"  # Adjust this path as needed
    remote_debugging_port = 9222

    # Command to start Chrome with remote debugging enabled
    command = [
        chrome_path,
        f"--remote-debugging-port={remote_debugging_port}",
        # f"--user-data-dir={user_data_dir}",
        url
    ]

    # Launch Chrome
    subprocess.Popen(command)

url = "https://www.imdb.com/search/title/?user_rating=6.1,10"
# Launch Chrome with the target URL
launch_chrome_with_debugging(url)

# Wait for a few seconds to ensure Chrome has started
time.sleep(5)

# %%
# Function to get the WebSocket Debugger URL
def get_websocket_debugger_url():
    response = requests.get('http://localhost:9222/json')
    if response.status_code == 200:
        json_data = response.json()
        for page in json_data:
            if "imdb" in page['url']:  # Match any Amazon page
                return page['webSocketDebuggerUrl']
    return None

# Check if Chrome is running with remote debugging
websocket_debugger_url = get_websocket_debugger_url()
if not websocket_debugger_url:
    raise Exception("Could not get the WebSocket debugger URL. "
                    "Make sure Chrome is running with remote debugging enabled.")

# Set up Selenium to use the existing Chrome instance
chrome_options = Options()
chrome_options.debugger_address = "localhost:9222"

# Set a custom user agent (optional)
user_agent = ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
              "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
chrome_options.add_argument(f"user-agent={user_agent}")

# Initialize WebDriver
driver = webdriver.Chrome(options=chrome_options)

# %% [markdown]
# # Extracting movies index - Title and link

# %%
# Constants
MAX_TITLES_BY_LOWER_BOUND = {
    1: 5000,
    3.1: 5000,
    6.1: 2500
}
SCROLLING_PERCENTAGE = 0.95
WAIT_TIME = 5  # Time to wait after scrolling or clicking

class movie_index_extractor:
    def __init__(self,driver):
        self.driver = driver
        self.base_url = "https://www.imdb.com/search/title/?user_rating={lower_bound},{upper_bound}"
    
    def sort_by_user_rating_count_desc(self):
        dropdown_label = self.driver.find_element(By.CLASS_NAME, "ipc-simple-select__input")
        dropdown_label.click()
        time.sleep(2)  # Wait for options to appear

        select_element = self.driver.find_element(By.ID, "adv-srch-sort-by")
        select = Select(select_element)
        select.select_by_value("USER_RATING_COUNT")  # Select "Number of Ratings"
        time.sleep(3)
        
        sort_button = self.driver.find_element(By.ID,'adv-srch-sort-order')
        sort_button.click()
        time.sleep(3)

    def scroll_to_element(self,element):
        """Scrolls smoothly to the given element."""
        driver.execute_script("arguments[0].scrollIntoView({behavior: 'smooth', block: 'center'});", element)
        time.sleep(2)  # Small delay for UI adjustment
        
    def click_button(self):
        """Finds and clicks the 'See More' button, if available."""
        try:
            button = WebDriverWait(driver, 10).until(
                EC.element_to_be_clickable((By.XPATH, "//button[contains(@class, 'ipc-see-more__button')]"))
            )
            self.scroll_to_element(button)
            driver.execute_script("arguments[0].click();", button)  # JavaScript click to avoid interception issues
            logger.info("Clicked 'See More' button.")
            time.sleep(WAIT_TIME)  # Allow time for new content to load
        except Exception as e:
            logger.info("No more 'See More' button found or an error occurred:", e)
            return False  # Stop execution if button isn't found
        return True

    def collect_reviews(self):
        """Collects the review elements from the page."""
        return driver.find_elements(By.CLASS_NAME, "ipc-metadata-list-summary-item")
    
    def extract_movie_data(self, titles):
            """Extracts movie titles and links from collected elements."""
            movie_data = []

            for movie_element in tqdm(titles, desc="Extracting titles and links"):
                try:
                    raw_title = movie_element.find_element(By.XPATH, ".//h3[contains(@class, 'ipc-title__text')]").text
                    movie_title = re.sub(r"^\d+\.\s*", "", raw_title)  # Remove ranking numbers
                    movie_link = movie_element.find_element(By.TAG_NAME, 'a').get_attribute('href')
                    movie_data.append((movie_title, movie_link))
                except Exception as e:
                    logger.error(f"Error extracting movie data: {e}")

            df_movies = pd.DataFrame(movie_data, columns=["Title", "IMDb Link"])
            df_movies.drop_duplicates(subset=['Title'], inplace=True)
            return df_movies
        
    def save_to_csv(self, df_movies, lower_bound, upper_bound):
        """Saves extracted movie data to CSV."""
        file_path = f"C:/Users/Harish Raju/Desktop/projects/IMDB/web_scrapper/data/Movies_index_rating_{lower_bound}_{upper_bound}.csv"
        df_movies.to_csv(file_path, index=False)
        logger.info(f"Saved {len(df_movies)} movies to {file_path}")
        
    def start_extraction(self):
            """Main function to start movie extraction for different rating bounds."""
            bounds = [
                (1, 3),
                (3.1, 6),
                (6.1, 10)
            ]

            for lower_bound, upper_bound in bounds:
                logger.info(f"Starting {lower_bound} to {upper_bound}")
                url = self.base_url.format(lower_bound=lower_bound, upper_bound=upper_bound)
                self.driver.get(url)
                self.sort_by_user_rating_count_desc()
                max_titles = MAX_TITLES_BY_LOWER_BOUND.get(lower_bound, 2000)  # Default to 2000 if not found
                logger.info(f"Extracting up to {max_titles} reviews from URL: {url}")

                while True:
                    if not self.click_button():  
                        logger.warning("No 'See More' button found, stopping extraction for this range.")
                        break

                    titles = self.collect_reviews()
                    logger.info(f"Total Reviews Collected: {len(titles)}")

                    if len(titles) >= max_titles:
                        logger.info("Reached max limit, stopping extraction.")
                        break
            
                logger.info('extracting movie data')
                df_movies = self.extract_movie_data(titles)
                
                self.save_to_csv(df_movies, lower_bound, upper_bound)

# %%
scraper = movie_index_extractor(driver)
scraper.start_extraction()
# Out:
# 2025-03-12 15:53:34 - [INFO] - (537093880.py:85) - Starting 1 to 3
# 2025-03-12 15:53:47 - [INFO] - (537093880.py:90) - Extracting up to 5000 reviews from URL: https://www.imdb.com/search/title/?user_rating=1,3
# 2025-03-12 15:53:49 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:53:55 - [INFO] - (537093880.py:98) - Total Reviews Collected: 99
# 2025-03-12 15:53:57 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:02 - [INFO] - (537093880.py:98) - Total Reviews Collected: 149
# 2025-03-12 15:54:04 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:09 - [INFO] - (537093880.py:98) - Total Reviews Collected: 199
# 2025-03-12 15:54:11 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:16 - [INFO] - (537093880.py:98) - Total Reviews Collected: 249
# 2025-03-12 15:54:18 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:23 - [INFO] - (537093880.py:98) - Total Reviews Collected: 299
# 2025-03-12 15:54:25 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:30 - [INFO] - (537093880.py:98) - Total Reviews Collected: 349
# 2025-03-12 15:54:32 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:38 - [INFO] - (537093880.py:98) - Total Reviews Collected: 399
# 2025-03-12 15:54:40 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:45 - [INFO] - (537093880.py:98) - Total Reviews Collected: 449
# 2025-03-12 15:54:47 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:52 - [INFO] - (537093880.py:98) - Total Reviews Collected: 499
# 2025-03-12 15:54:54 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:54:59 - [INFO] - (537093880.py:98) - Total Reviews Collected: 549
# 2025-03-12 15:55:01 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:55:06 - [INFO] - (537093880.py:98) - Total Reviews Collected: 599
# 2025-03-12 15:55:08 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:55:13 - [INFO] - (537093880.py:98) - Total Reviews Collected: 649
# 2025-03-12 15:55:15 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:55:20 - [INFO] - (537093880.py:98) - Total Reviews Collected: 699
# 2025-03-12 15:55:23 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:55:28 - [INFO] - (537093880.py:98) - Total Reviews Collected: 749
# 2025-03-12 15:55:30 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:55:35 - [INFO] - (537093880.py:98) - Total Reviews Collected: 799
# 2025-03-12 15:55:37 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:55:42 - [INFO] - (537093880.py:98) - Total Reviews Collected: 849
# 2025-03-12 15:55:44 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:55:49 - [INFO] - (537093880.py:98) - Total Reviews Collected: 898
# 2025-03-12 15:55:51 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:55:56 - [INFO] - (537093880.py:98) - Total Reviews Collected: 948
# 2025-03-12 15:55:58 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:56:04 - [INFO] - (537093880.py:98) - Total Reviews Collected: 998
# 2025-03-12 15:56:06 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:56:11 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1048
# 2025-03-12 15:56:13 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:56:18 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1098
# 2025-03-12 15:56:20 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:56:25 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1148
# 2025-03-12 15:56:27 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:56:32 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1198
# 2025-03-12 15:56:34 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:56:40 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1248
# 2025-03-12 15:56:42 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:56:47 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1298
# 2025-03-12 15:56:49 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:56:54 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1348
# 2025-03-12 15:56:56 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:57:01 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1398
# 2025-03-12 15:57:03 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:57:08 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1448
# 2025-03-12 15:57:11 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:57:16 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1498
# 2025-03-12 15:57:18 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:57:23 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1548
# 2025-03-12 15:57:25 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:57:30 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1598
# 2025-03-12 15:57:32 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:57:37 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1648
# 2025-03-12 15:57:40 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:57:45 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1698
# 2025-03-12 15:57:47 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:57:52 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1748
# 2025-03-12 15:57:55 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:00 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1798
# 2025-03-12 15:58:02 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:07 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1848
# 2025-03-12 15:58:10 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1898
# 2025-03-12 15:58:17 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:22 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1948
# 2025-03-12 15:58:25 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:30 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1998
# 2025-03-12 15:58:32 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:37 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2048
# 2025-03-12 15:58:39 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:45 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2098
# 2025-03-12 15:58:47 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:52 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2148
# 2025-03-12 15:58:54 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:58:59 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2198
# 2025-03-12 15:59:01 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:59:07 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2248
# 2025-03-12 15:59:10 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:59:17 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2298
# 2025-03-12 15:59:19 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:59:25 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2348
# 2025-03-12 15:59:27 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:59:32 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2398
# 2025-03-12 15:59:34 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:59:39 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2448
# 2025-03-12 15:59:41 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:59:47 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2498
# 2025-03-12 15:59:49 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 15:59:54 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2548
# 2025-03-12 15:59:56 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:00:01 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2598
# 2025-03-12 16:00:03 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:00:10 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2648
# 2025-03-12 16:00:12 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:00:18 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2698
# 2025-03-12 16:00:20 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:00:26 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2748
# 2025-03-12 16:00:28 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:00:34 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2798
# 2025-03-12 16:00:36 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:00:42 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2848
# 2025-03-12 16:00:44 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:00:49 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2898
# 2025-03-12 16:00:51 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:00:57 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2948
# 2025-03-12 16:00:59 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:01:07 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2998
# 2025-03-12 16:01:09 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:01:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3048
# 2025-03-12 16:01:17 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:01:23 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3098
# 2025-03-12 16:01:25 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:01:32 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3148
# 2025-03-12 16:01:34 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:01:42 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3198
# 2025-03-12 16:01:45 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:01:51 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3248
# 2025-03-12 16:01:53 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:02:00 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3298
# 2025-03-12 16:02:02 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:02:11 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3348
# 2025-03-12 16:02:13 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:02:20 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3398
# 2025-03-12 16:02:23 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:02:29 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3448
# 2025-03-12 16:02:32 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:02:38 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3497
# 2025-03-12 16:02:40 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:02:49 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3547
# 2025-03-12 16:02:52 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:03:01 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3597
# 2025-03-12 16:03:03 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:03:10 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3647
# 2025-03-12 16:03:12 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:03:20 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3696
# 2025-03-12 16:03:22 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:03:30 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3746
# 2025-03-12 16:03:32 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:03:40 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3796
# 2025-03-12 16:03:42 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:03:49 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3846
# 2025-03-12 16:03:51 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:03:59 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3896
# 2025-03-12 16:04:02 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:04:10 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3946
# 2025-03-12 16:04:12 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:04:21 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3996
# 2025-03-12 16:04:23 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:04:33 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4046
# 2025-03-12 16:04:35 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:04:44 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4095
# 2025-03-12 16:04:46 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:04:54 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4145
# 2025-03-12 16:04:56 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:05:05 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4195
# 2025-03-12 16:05:07 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:05:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4245
# 2025-03-12 16:05:17 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:05:26 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4295
# 2025-03-12 16:05:28 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:05:36 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4345
# 2025-03-12 16:05:39 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:05:48 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4395
# 2025-03-12 16:05:50 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:05:58 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4445
# 2025-03-12 16:06:01 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:06:09 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4495
# 2025-03-12 16:06:12 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:06:21 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4545
# 2025-03-12 16:06:23 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:06:32 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4594
# 2025-03-12 16:06:34 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:06:43 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4644
# 2025-03-12 16:06:46 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:06:55 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4694
# 2025-03-12 16:06:57 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:07:06 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4744
# 2025-03-12 16:07:08 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:07:17 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4794
# 2025-03-12 16:07:20 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:07:29 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4844
# 2025-03-12 16:07:31 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:07:41 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4894
# 2025-03-12 16:07:43 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:07:53 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4944
# 2025-03-12 16:07:55 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:08:05 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4994
# 2025-03-12 16:08:07 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:08:17 - [INFO] - (537093880.py:98) - Total Reviews Collected: 5044
# 2025-03-12 16:08:17 - [INFO] - (537093880.py:101) - Reached max limit, stopping extraction.
# 2025-03-12 16:08:17 - [INFO] - (537093880.py:104) - extracting movie data
# Extracting titles and links: 100%|██████████| 5044/5044 [10:40<00:00,  7.87it/s]
# 2025-03-12 16:18:58 - [INFO] - (537093880.py:74) - Saved 4879 movies to C:/Users/Harish Raju/Desktop/projects/IMDB/web_scrapper/data/Movies_index_rating_1_3.csv
# 2025-03-12 16:18:58 - [INFO] - (537093880.py:85) - Starting 3.1 to 6
# 2025-03-12 16:19:14 - [INFO] - (537093880.py:90) - Extracting up to 5000 reviews from URL: https://www.imdb.com/search/title/?user_rating=3.1,6
# 2025-03-12 16:19:16 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:19:21 - [INFO] - (537093880.py:98) - Total Reviews Collected: 100
# 2025-03-12 16:19:23 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:19:28 - [INFO] - (537093880.py:98) - Total Reviews Collected: 150
# 2025-03-12 16:19:30 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:19:36 - [INFO] - (537093880.py:98) - Total Reviews Collected: 200
# 2025-03-12 16:19:38 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:19:43 - [INFO] - (537093880.py:98) - Total Reviews Collected: 250
# 2025-03-12 16:19:45 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:19:50 - [INFO] - (537093880.py:98) - Total Reviews Collected: 300
# 2025-03-12 16:19:52 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:19:57 - [INFO] - (537093880.py:98) - Total Reviews Collected: 350
# 2025-03-12 16:19:59 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:20:04 - [INFO] - (537093880.py:98) - Total Reviews Collected: 400
# 2025-03-12 16:20:06 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:20:11 - [INFO] - (537093880.py:98) - Total Reviews Collected: 450
# 2025-03-12 16:20:13 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:20:18 - [INFO] - (537093880.py:98) - Total Reviews Collected: 500
# 2025-03-12 16:20:20 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:20:26 - [INFO] - (537093880.py:98) - Total Reviews Collected: 550
# 2025-03-12 16:20:28 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:20:33 - [INFO] - (537093880.py:98) - Total Reviews Collected: 600
# 2025-03-12 16:20:35 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:20:40 - [INFO] - (537093880.py:98) - Total Reviews Collected: 650
# 2025-03-12 16:20:42 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:20:48 - [INFO] - (537093880.py:98) - Total Reviews Collected: 700
# 2025-03-12 16:20:50 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:20:55 - [INFO] - (537093880.py:98) - Total Reviews Collected: 750
# 2025-03-12 16:20:57 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:21:02 - [INFO] - (537093880.py:98) - Total Reviews Collected: 800
# 2025-03-12 16:21:04 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:21:09 - [INFO] - (537093880.py:98) - Total Reviews Collected: 850
# 2025-03-12 16:21:11 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:21:17 - [INFO] - (537093880.py:98) - Total Reviews Collected: 900
# 2025-03-12 16:21:19 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:21:25 - [INFO] - (537093880.py:98) - Total Reviews Collected: 950
# 2025-03-12 16:21:27 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:21:32 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1000
# 2025-03-12 16:21:34 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:21:39 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1050
# 2025-03-12 16:21:42 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:21:47 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1100
# 2025-03-12 16:21:49 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:21:57 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1150
# 2025-03-12 16:21:59 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:22:05 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1200
# 2025-03-12 16:22:07 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:22:13 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1250
# 2025-03-12 16:22:15 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:22:21 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1300
# 2025-03-12 16:22:23 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:22:29 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1350
# 2025-03-12 16:22:31 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:22:38 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1400
# 2025-03-12 16:22:40 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:22:46 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1450
# 2025-03-12 16:22:48 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:22:56 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1500
# 2025-03-12 16:22:58 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:23:04 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1550
# 2025-03-12 16:23:07 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:23:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1600
# 2025-03-12 16:23:17 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:23:24 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1650
# 2025-03-12 16:23:26 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:23:32 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1700
# 2025-03-12 16:23:35 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:23:41 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1750
# 2025-03-12 16:23:43 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:23:50 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1800
# 2025-03-12 16:23:52 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:23:58 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1850
# 2025-03-12 16:24:01 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:24:08 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1900
# 2025-03-12 16:24:10 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:24:17 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1950
# 2025-03-12 16:24:20 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:24:27 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2000
# 2025-03-12 16:24:29 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:24:37 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2050
# 2025-03-12 16:24:39 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:24:46 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2100
# 2025-03-12 16:24:49 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:24:55 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2150
# 2025-03-12 16:24:57 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:25:04 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2200
# 2025-03-12 16:25:06 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:25:12 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2250
# 2025-03-12 16:25:14 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:25:21 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2300
# 2025-03-12 16:25:23 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:25:29 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2350
# 2025-03-12 16:25:31 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:25:38 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2400
# 2025-03-12 16:25:40 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:25:47 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2450
# 2025-03-12 16:25:49 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:25:56 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2500
# 2025-03-12 16:25:58 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:26:07 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2550
# 2025-03-12 16:26:09 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:26:16 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2600
# 2025-03-12 16:26:18 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:26:25 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2650
# 2025-03-12 16:26:27 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:26:34 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2700
# 2025-03-12 16:26:36 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:26:43 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2750
# 2025-03-12 16:26:46 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:26:53 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2800
# 2025-03-12 16:26:56 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:27:06 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2850
# 2025-03-12 16:27:08 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:27:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2900
# 2025-03-12 16:27:18 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:27:25 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2950
# 2025-03-12 16:27:27 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:27:37 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3000
# 2025-03-12 16:27:40 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:27:47 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3050
# 2025-03-12 16:27:49 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:27:57 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3100
# 2025-03-12 16:27:59 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:28:07 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3150
# 2025-03-12 16:28:09 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:28:19 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3200
# 2025-03-12 16:28:21 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:28:29 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3250
# 2025-03-12 16:28:31 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:28:41 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3300
# 2025-03-12 16:28:43 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:28:51 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3350
# 2025-03-12 16:28:53 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:29:01 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3400
# 2025-03-12 16:29:04 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:29:14 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3450
# 2025-03-12 16:29:16 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:29:25 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3499
# 2025-03-12 16:29:27 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:29:35 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3549
# 2025-03-12 16:29:37 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:29:46 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3599
# 2025-03-12 16:29:48 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:29:56 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3649
# 2025-03-12 16:29:58 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:30:07 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3699
# 2025-03-12 16:30:09 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:30:18 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3749
# 2025-03-12 16:30:20 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:30:29 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3799
# 2025-03-12 16:30:31 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:30:40 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3849
# 2025-03-12 16:30:42 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:30:51 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3899
# 2025-03-12 16:30:54 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:31:03 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3949
# 2025-03-12 16:31:05 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:31:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 3999
# 2025-03-12 16:31:17 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:31:27 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4048
# 2025-03-12 16:31:29 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:31:39 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4098
# 2025-03-12 16:31:41 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:31:51 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4148
# 2025-03-12 16:31:53 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:32:03 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4197
# 2025-03-12 16:32:05 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:32:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4247
# 2025-03-12 16:32:18 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:32:28 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4297
# 2025-03-12 16:32:30 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:32:40 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4347
# 2025-03-12 16:32:43 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:32:53 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4397
# 2025-03-12 16:32:55 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:33:06 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4446
# 2025-03-12 16:33:08 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:33:18 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4496
# 2025-03-12 16:33:20 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:33:31 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4546
# 2025-03-12 16:33:33 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:33:44 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4596
# 2025-03-12 16:33:46 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:33:57 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4646
# 2025-03-12 16:33:59 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:34:12 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4696
# 2025-03-12 16:34:14 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:34:25 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4746
# 2025-03-12 16:34:27 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:34:38 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4796
# 2025-03-12 16:34:40 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:34:51 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4846
# 2025-03-12 16:34:53 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:35:06 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4896
# 2025-03-12 16:35:08 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:35:20 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4944
# 2025-03-12 16:35:22 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:35:35 - [INFO] - (537093880.py:98) - Total Reviews Collected: 4994
# 2025-03-12 16:35:38 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:35:50 - [INFO] - (537093880.py:98) - Total Reviews Collected: 5044
# 2025-03-12 16:35:50 - [INFO] - (537093880.py:101) - Reached max limit, stopping extraction.
# 2025-03-12 16:35:50 - [INFO] - (537093880.py:104) - extracting movie data
# Extracting titles and links: 100%|██████████| 5044/5044 [09:50<00:00,  8.54it/s]
# 2025-03-12 16:45:40 - [INFO] - (537093880.py:74) - Saved 3780 movies to C:/Users/Harish Raju/Desktop/projects/IMDB/web_scrapper/data/Movies_index_rating_3.1_6.csv
# 2025-03-12 16:45:40 - [INFO] - (537093880.py:85) - Starting 6.1 to 10
# 2025-03-12 16:45:59 - [INFO] - (537093880.py:90) - Extracting up to 2500 reviews from URL: https://www.imdb.com/search/title/?user_rating=6.1,10
# 2025-03-12 16:46:01 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:46:06 - [INFO] - (537093880.py:98) - Total Reviews Collected: 100
# 2025-03-12 16:46:08 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:46:13 - [INFO] - (537093880.py:98) - Total Reviews Collected: 150
# 2025-03-12 16:46:15 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:46:20 - [INFO] - (537093880.py:98) - Total Reviews Collected: 200
# 2025-03-12 16:46:22 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:46:28 - [INFO] - (537093880.py:98) - Total Reviews Collected: 250
# 2025-03-12 16:46:30 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:46:35 - [INFO] - (537093880.py:98) - Total Reviews Collected: 300
# 2025-03-12 16:46:37 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:46:42 - [INFO] - (537093880.py:98) - Total Reviews Collected: 350
# 2025-03-12 16:46:44 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:46:49 - [INFO] - (537093880.py:98) - Total Reviews Collected: 400
# 2025-03-12 16:46:51 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:46:56 - [INFO] - (537093880.py:98) - Total Reviews Collected: 450
# 2025-03-12 16:46:58 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:47:03 - [INFO] - (537093880.py:98) - Total Reviews Collected: 500
# 2025-03-12 16:47:05 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:47:10 - [INFO] - (537093880.py:98) - Total Reviews Collected: 550
# 2025-03-12 16:47:12 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:47:18 - [INFO] - (537093880.py:98) - Total Reviews Collected: 600
# 2025-03-12 16:47:20 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:47:25 - [INFO] - (537093880.py:98) - Total Reviews Collected: 650
# 2025-03-12 16:47:27 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:47:32 - [INFO] - (537093880.py:98) - Total Reviews Collected: 700
# 2025-03-12 16:47:34 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:47:39 - [INFO] - (537093880.py:98) - Total Reviews Collected: 750
# 2025-03-12 16:47:41 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:47:46 - [INFO] - (537093880.py:98) - Total Reviews Collected: 800
# 2025-03-12 16:47:48 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:47:53 - [INFO] - (537093880.py:98) - Total Reviews Collected: 850
# 2025-03-12 16:47:56 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:48:01 - [INFO] - (537093880.py:98) - Total Reviews Collected: 900
# 2025-03-12 16:48:03 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:48:08 - [INFO] - (537093880.py:98) - Total Reviews Collected: 950
# 2025-03-12 16:48:10 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:48:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1000
# 2025-03-12 16:48:17 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:48:23 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1050
# 2025-03-12 16:48:25 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:48:30 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1100
# 2025-03-12 16:48:32 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:48:38 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1150
# 2025-03-12 16:48:40 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:48:45 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1200
# 2025-03-12 16:48:47 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:48:53 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1250
# 2025-03-12 16:48:55 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:49:00 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1300
# 2025-03-12 16:49:02 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:49:08 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1350
# 2025-03-12 16:49:11 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:49:16 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1400
# 2025-03-12 16:49:18 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:49:26 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1450
# 2025-03-12 16:49:28 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:49:33 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1500
# 2025-03-12 16:49:35 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:49:41 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1550
# 2025-03-12 16:49:43 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:49:49 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1600
# 2025-03-12 16:49:51 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:49:57 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1650
# 2025-03-12 16:49:59 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:50:06 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1700
# 2025-03-12 16:50:08 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:50:14 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1750
# 2025-03-12 16:50:16 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:50:23 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1800
# 2025-03-12 16:50:25 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:50:32 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1850
# 2025-03-12 16:50:34 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:50:40 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1900
# 2025-03-12 16:50:42 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:50:48 - [INFO] - (537093880.py:98) - Total Reviews Collected: 1950
# 2025-03-12 16:50:50 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:50:57 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2000
# 2025-03-12 16:50:59 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:51:06 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2050
# 2025-03-12 16:51:08 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:51:15 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2100
# 2025-03-12 16:51:17 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:51:23 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2150
# 2025-03-12 16:51:26 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:51:33 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2200
# 2025-03-12 16:51:35 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:51:42 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2250
# 2025-03-12 16:51:44 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:51:51 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2300
# 2025-03-12 16:51:54 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:52:01 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2350
# 2025-03-12 16:52:03 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:52:10 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2400
# 2025-03-12 16:52:12 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:52:20 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2450
# 2025-03-12 16:52:22 - [INFO] - (537093880.py:42) - Clicked 'See More' button.
# 2025-03-12 16:52:30 - [INFO] - (537093880.py:98) - Total Reviews Collected: 2500
# 2025-03-12 16:52:30 - [INFO] - (537093880.py:101) - Reached max limit, stopping extraction.
# 2025-03-12 16:52:30 - [INFO] - (537093880.py:104) - extracting movie data
# Extracting titles and links: 100%|██████████| 2500/2500 [03:24<00:00, 12.24it/s]
# 2025-03-12 16:55:54 - [INFO] - (537093880.py:74) - Saved 2453 movies to C:/Users/Harish Raju/Desktop/projects/IMDB/web_scrapper/data/Movies_index_rating_6.1_10.csv

# %%
    # def start_extraction(self):
    #     bounds = [
    #         (1,3),
    #         (3.1,6),
    #         (6,10)
    #     ]
    #     for lower_bound,upper_bound in bounds:
    #         url = self.base_url.format(lower_bound = lower_bound,upper_bound = upper_bound)
    #         self.driver.get(url)
    #         max_titles = MAX_TITLES_BY_LOWER_BOUND[lower_bound]
    #         print(f"extracting {max_titles}reviews from url")
    #         print("Attempting to click 'See More' button...")
    #         if not self.click_button():  # If button is not found, exit loop
    #             break
    #         titles = self.collect_reviews()
    #         print(f"Total Reviews Collected: {len(titles)}")
            
    #         if len(titles) >= max_titles:
    #             break

    #         movie_data = []

    #         # Iterate through each extracted 'li' element containing movie details
    #         for movie_element in tqdm(titles,desc = 'Extracting titles and link'):
    #             # Extract the movie title from the 'h3' tag inside the element
    #             raw_title = movie_element.find_element(By.XPATH, ".//h3[contains(@class, 'ipc-title__text')]").text
    #             # print(f"Extracting: {raw_title}")

    #             # Remove leading numbers (e.g., "1. The Shawshank Redemption" → "The Shawshank Redemption")
    #             movie_title = re.sub(r"^\d+\.\s*", "", raw_title)

    #             # Extract the hyperlink to the movie's IMDb page
    #             movie_link = movie_element.find_element(By.TAG_NAME, 'a').get_attribute('href')

    #             # Append data as a tuple (no risk of overwriting)
    #             movie_data.append((movie_title, movie_link))

    #         # Convert list to DataFrame
    #         df_movies = pd.DataFrame(movie_data, columns=["Title", "IMDb Link"])

    #         # Display the number of rows
    #         print(f"Total movies extracted: {len(df_movies)}")
            
    #         df_movies = df_movies.drop_duplicates(subset=['Title']).reset_index(drop=True)
            
    #         df_movies.to_csv(f'../data/Movies_index_rating_{lower_bound}_{upper_bound}.csv',index=False)

# %%
# driver.get(url)

# time.sleep(3)

# %%
# import time
# import logger
# import re
# import pandas as pd
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support.ui import WebDriverWait, Select
# from selenium.webdriver.support import expected_conditions as EC
# from tqdm import tqdm

# # Configure logger
# logger.basicConfig(level=logger.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# # IMDb URL template (modify this as needed)
# BASE_URL = "https://www.imdb.com/search/title/?user_rating={lower_bound},{upper_bound}&sort=num_votes,desc"

# # Define rating categories
# RATING_CATEGORIES = {
#     "Low": (1, 3),
#     "Medium": (3.1, 6),
#     "High": (6.1, 10)
# }


# # Constants
# MAX_TITLES = 2000  # Limit on movie titles
# WAIT_TIME = 5       # Wait time for loading content

# def scroll_to_element(element):
#     """Scrolls smoothly to the given element."""
#     driver.execute_script("arguments[0].scrollIntoView({behavior: 'smooth', block: 'center'});", element)
#     time.sleep(2)  # Small delay for UI adjustment

# def click_see_more():
#     """Clicks the 'See More' button to load more results."""
#     try:
#         button = WebDriverWait(driver, 10).until(
#             EC.element_to_be_clickable((By.XPATH, "//button[contains(@class, 'ipc-see-more__button')]")
#         ))
#         scroll_to_element(button)
#         driver.execute_script("arguments[0].click();", button)
#         time.sleep(WAIT_TIME)  # Allow new content to load
#         return True
#     except Exception as e:
#         logger.warning("No more 'See More' button found or an error occurred: %s", e)
#         return False

# def collect_reviews():
#     """Collects the review elements from the page."""
#     return driver.find_elements(By.CLASS_NAME, "ipc-metadata-list-summary-item")

# def extract_movie_data(titles, rating_category):
#     """Extracts movie titles and links from the collected elements."""
#     movie_data = []
#     for movie_element in tqdm(titles, desc=f'Extracting movies ({rating_category})'):
#         try:
#             raw_title = movie_element.find_element(By.XPATH, ".//h3[contains(@class, 'ipc-title__text')]").text
#             movie_title = re.sub(r"^\d+\.\s*", "", raw_title)  # Remove ranking numbers
#             movie_link = movie_element.find_element(By.TAG_NAME, 'a').get_attribute('href')
#             movie_data.append((movie_title, movie_link, rating_category))
#         except Exception as e:
#             logger.error("Error extracting data: %s", e)
#     return pd.DataFrame(movie_data, columns=["Title", "IMDb Link", "Rating Category"])

# def scrape_movies_by_rating(lower_bound, upper_bound, category_name):
#     """Scrapes movies for a given rating range and category."""
#     url = BASE_URL.format(lower_bound=lower_bound, upper_bound=upper_bound)
#     driver.get(url)
#     time.sleep(WAIT_TIME)  # Allow initial page load

#     titles = []
#     while True:
#         if not click_see_more():  # Stop if no more pages
#             break
#         titles.extend(collect_reviews())
#         if len(titles) >= MAX_TITLES:
#             break

#     df_movies = extract_movie_data(titles, category_name)
#     df_movies.drop_duplicates(subset=['Title'], inplace=True)
#     return df_movies

# # Scrape movies for each rating category
# all_dataframes = []
# for category, (lower_bound, upper_bound) in RATING_CATEGORIES.items():
#     logger.info("Scraping movies for rating category: %s", category)
#     df = scrape_movies_by_rating(lower_bound, upper_bound, category)
#     all_dataframes.append(df)

# # Combine all categories into one DataFrame
# final_df = pd.concat(all_dataframes, ignore_index=True)
# output_file = r'C:\Users\Harish Raju\Desktop\projects\IMDB\web_scrapper\data\Movies_by_rating.csv'
# final_df.to_csv(output_file, index=False)

# logger.info("Scraping completed. Data saved to: %s", output_file)

# driver.quit()

# %%
# import time
# import logger
# import re
# import pandas as pd
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support.ui import WebDriverWait, Select
# from selenium.webdriver.support import expected_conditions as EC
# from tqdm import tqdm

# # Configure logger
# logger.basicConfig(level=logger.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# # IMDb URL template (modify this as needed)
# BASE_URL = "https://www.imdb.com/search/title/?user_rating={lower_bound},{upper_bound}&sort=num_votes,desc"

# # Define rating categories
# RATING_CATEGORIES = {
#     "Low": (1, 3),
#     "Medium": (3.1, 6),
#     "High": (6.1, 10)
# }

# # Selenium WebDriver setup
# # options = webdriver.ChromeOptions()
# # options.add_argument("--headless")  # Run in headless mode

# # driver = webdriver.Chrome(options=options)

# # Constants
# MAX_TITLES = 2000  # Limit on movie titles
# WAIT_TIME = 5       # Wait time for loading content

# def scroll_to_element(element):
#     """Scrolls smoothly to the given element."""
#     logger.info("Scrolling to element...")
#     driver.execute_script("arguments[0].scrollIntoView({behavior: 'smooth', block: 'center'});", element)
#     time.sleep(2)  # Small delay for UI adjustment

# def click_see_more():
#     """Clicks the 'See More' button to load more results."""
#     try:
#         logger.info("Attempting to click 'See More' button...")
#         button = WebDriverWait(driver, 10).until(
#             EC.element_to_be_clickable((By.XPATH, "//button[contains(@class, 'ipc-see-more__button')]")
#         ))
#         scroll_to_element(button)
#         driver.execute_script("arguments[0].click();", button)
#         logger.info("Successfully clicked 'See More' button.")
#         time.sleep(WAIT_TIME)  # Allow new content to load
#         return True
#     except Exception as e:
#         logger.warning("No more 'See More' button found or an error occurred: %s", e)
#         return False

# def collect_reviews():
#     """Collects the review elements from the page."""
#     logger.info("Collecting review elements from the page...")
#     return driver.find_elements(By.CLASS_NAME, "ipc-metadata-list-summary-item")

# def extract_movie_data(titles, rating_category):
#     """Extracts movie titles and links from the collected elements."""
#     logger.info("Extracting movie data for category: %s", rating_category)
#     movie_data = []
#     for movie_element in tqdm(titles, desc=f'Extracting movies ({rating_category})'):
#         try:
#             raw_title = movie_element.find_element(By.XPATH, ".//h3[contains(@class, 'ipc-title__text')]").text
#             movie_title = re.sub(r"^\d+\.\s*", "", raw_title)  # Remove ranking numbers
#             movie_link = movie_element.find_element(By.TAG_NAME, 'a').get_attribute('href')
#             movie_data.append((movie_title, movie_link, rating_category))
#         except Exception as e:
#             logger.error("Error extracting data: %s", e)
#     logger.info("Extracted %d movies for category: %s", len(movie_data), rating_category)
#     return pd.DataFrame(movie_data, columns=["Title", "IMDb Link", "Rating Category"])

# def scrape_movies_by_rating(lower_bound, upper_bound, category_name):
#     """Scrapes movies for a given rating range and category."""
#     url = BASE_URL.format(lower_bound=lower_bound, upper_bound=upper_bound)
#     logger.info("Navigating to URL: %s", url)
#     driver.get(url)
#     time.sleep(WAIT_TIME)  # Allow initial page load

#     titles = []
#     while True:
#         if not click_see_more():  # Stop if no more pages
#             break
#         new_titles = collect_reviews()
#         titles.extend(new_titles)
#         logger.info("Total movies collected so far: %d", len(titles))
#         if len(titles) >= MAX_TITLES:
#             logger.info("Reached maximum limit of %d movies.", MAX_TITLES)
#             break

#     df_movies = extract_movie_data(titles, category_name)
#     df_movies.drop_duplicates(subset=['Title'], inplace=True)
#     logger.info("Final count of unique movies in category %s: %d", category_name, len(df_movies))
#     return df_movies

# # Scrape movies for each rating category
# all_dataframes = []
# for category, (lower_bound, upper_bound) in RATING_CATEGORIES.items():
#     logger.info("Starting scraping for rating category: %s", category)
#     df = scrape_movies_by_rating(lower_bound, upper_bound, category)
#     all_dataframes.append(df)

# # Combine all categories into one DataFrame
# final_df = pd.concat(all_dataframes, ignore_index=True)
# output_file = r'C:\Users\Harish Raju\Desktop\projects\IMDB\web_scrapper\data\Movies_by_rating.csv'
# final_df.to_csv(output_file, index=False)

# logger.info("Scraping completed. Total movies extracted: %d", len(final_df))
# logger.info("Data saved to: %s", output_file)

# driver.quit()

# %%
# final_df['Rating Category'].value_counts()
